# %% [markdown]
# ![image.png](attachment:0ec0cbc3-b370-4cdd-b422-ff37d6ee5db2.png)
#
# ---
#
#
# ![image.png](attachment:5566c480-c44d-45cc-aaa8-d284eab7ac18.png)
#
# ---
#
# ![image.png](attachment:b8cdf19e-da9d-4237-84e9-c6870131e418.png)
#
# ---
#
# ![image.png](attachment:60a6b5d2-1f05-419f-bd30-69c7e373c251.png)
#
# ---
#
# |

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import re
from bs4 import BeautifulSoup

# %%
df = pd.read_csv('../data/raw/train.csv')

# %%
new_df = df.sample(30000,random_state=2)# randomstate 4 lakhs data wil llietraly fresze my system so just using samples

# %%
new_df.head()
# Out:
#             id    qid1    qid2  \
# 398782  398782  496695  532029
# 115086  115086  187729  187730
# 327711  327711  454161  454162
# 367788  367788  498109  491396
# 151235  151235  237843   50930
#
#                                                 question1  \
# 398782  What is the best marketing automation tool for...
# 115086  I am poor but I want to invest. What should I do?
# 327711  I am from India and live abroad. I met a guy f...
# 367788  Why do so many people in the U.S. hate the sou...
# 151235                Consequences of Bhopal gas tragedy?
#
#                                                 question2  is_duplicate
# 398782  What is the best marketing automation tool for...             1
# 115086  I am quite poor and I want to be very rich. Wh...             0
# 327711  T.I.E.T to Thapar University to Thapar Univers...             0
# 367788  My boyfriend doesnt feel guilty when he hurts ...             0
# 151235  What was the reason behind the Bhopal gas trag...             0

# %%
# even tho we ont need to standardize or impoute missing vals problems still persist
# thsoe ,./';[!@#$%^&*()_ are annoying and will degrade model for sure so removing that becomes anotherhasle
def preprocess(q):
    
    q = str(q).lower().strip()
    
    #replace certain special characters with their string equivalents
    # as it will detoriatemodel uselessly they dont even carry any smeantiv meaning too
    q = q.replace('%', ' percent')
    q = q.replace('$', ' dollar ')
    q = q.replace('₹', ' rupee ')
    q = q.replace('€', ' euro ')
    q = q.replace('@', ' at ')
    
    # The pattern '[math]' appears around 900 times in the whole dataset.
    #literally hav no menin so just removing that forsake of increasng accuracya
    q = q.replace('[math]', '')
    
    #thise trailing zeroes are like noise to the system so preventing such
    # k thousands m million b billion 
    q = q.replace(',000,000,000 ', 'b ')
    q = q.replace(',000,000 ', 'm ')
    q = q.replace(',000 ', 'k ')
    q = re.sub(r'([0-9]+)000000000', r'\1b', q)
    q = re.sub(r'([0-9]+)000000', r'\1m', q)
    q = re.sub(r'([0-9]+)000', r'\1k', q)
    
    # Decontracting words like those stupid special character are pain in a... ankle
    # so removing apostrophe stuffs right away with proper uncondensed form
    # used these in wikipedia and stack overflow

    
    # https://en.wikipedia.org/wiki/Wikipedia%3aList_of_English_contractions
    # https://stackoverflow.com/a/19794953
    contractions = { 
    "ain't": "am not",
    "aren't": "are not",
    "can't": "can not",
    "can't've": "can not have",
    "'cause": "because",
    "could've": "could have",
    "couldn't": "could not",
    "couldn't've": "could not have",
    "didn't": "did not",
    "doesn't": "does not",
    "don't": "do not",
    "hadn't": "had not",
    "hadn't've": "had not have",
    "hasn't": "has not",
    "haven't": "have not",
    "he'd": "he would",
    "he'd've": "he would have",
    "he'll": "he will",
    "he'll've": "he will have",
    "he's": "he is",
    "how'd": "how did",
    "how'd'y": "how do you",
    "how'll": "how will",
    "how's": "how is",
    "i'd": "i would",
    "i'd've": "i would have",
    "i'll": "i will",
    "i'll've": "i will have",
    "i'm": "i am",
    "i've": "i have",
    "isn't": "is not",
    "it'd": "it would",
    "it'd've": "it would have",
    "it'll": "it will",
    "it'll've": "it will have",
    "it's": "it is",
    "let's": "let us",
    "ma'am": "madam",
    "mayn't": "may not",
    "might've": "might have",
    "mightn't": "might not",
    "mightn't've": "might not have",
    "must've": "must have",
    "mustn't": "must not",
    "mustn't've": "must not have",
    "needn't": "need not",
    "needn't've": "need not have",
    "o'clock": "of the clock",
    "oughtn't": "ought not",
    "oughtn't've": "ought not have",
    "shan't": "shall not",
    "sha'n't": "shall not",
    "shan't've": "shall not have",
    "she'd": "she would",
    "she'd've": "she would have",
    "she'll": "she will",
    "she'll've": "she will have",
    "she's": "she is",
    "should've": "should have",
    "shouldn't": "should not",
    "shouldn't've": "should not have",
    "so've": "so have",
    "so's": "so as",
    "that'd": "that would",
    "that'd've": "that would have",
    "that's": "that is",
    "there'd": "there would",
    "there'd've": "there would have",
    "there's": "there is",
    "they'd": "they would",
    "they'd've": "they would have",
    "they'll": "they will",
    "they'll've": "they will have",
    "they're": "they are",
    "they've": "they have",
    "to've": "to have",
    "wasn't": "was not",
    "we'd": "we would",
    "we'd've": "we would have",
    "we'll": "we will",
    "we'll've": "we will have",
    "we're": "we are",
    "we've": "we have",
    "weren't": "were not",
    "what'll": "what will",
    "what'll've": "what will have",
    "what're": "what are",
    "what's": "what is",
    "what've": "what have",
    "when's": "when is",
    "when've": "when have",
    "where'd": "where did",
    "where's": "where is",
    "where've": "where have",
    "who'll": "who will",
    "who'll've": "who will have",
    "who's": "who is",
    "who've": "who have",
    "why's": "why is",
    "why've": "why have",
    "will've": "will have",
    "won't": "will not",
    "won't've": "will not have",
    "would've": "would have",
    "wouldn't": "would not",
    "wouldn't've": "would not have",
    "y'all": "you all",
    "y'all'd": "you all would",
    "y'all'd've": "you all would have",
    "y'all're": "you all are",
    "y'all've": "you all have",
    "you'd": "you would",
    "you'd've": "you would have",
    "you'll": "you will",
    "you'll've": "you will have",
    "you're": "you are",
    "you've": "you have"
    }

    
    q_decontracted = []
# splitting each words on the basis of space and then applyig above made dictionary to normalize the meaning
    for word in q.split():
        if word in contractions:
            word = contractions[word]

        q_decontracted.append(word)

    q = ' '.join(q_decontracted)
    q = q.replace("'ve", " have")
    q = q.replace("n't", " not")
    q = q.replace("'re", " are")
    q = q.replace("'ll", " will")
    
    # Removing HTML tags
    q = BeautifulSoup(q)
    q = q.get_text()
    
    # Remove punctuations
    pattern = re.compile(r'\W')  # Use raw string literal
    q = re.sub(pattern, ' ', q).strip()

    
    return q

# %%
preprocess("Santosh SHRESTHA owner of 3 rolls royce and  $ 100000000000000000000 dollars and gold worth 3,000,000 why the %$#&@ you are flabbergasted >??? he ain't afraid <santosh>TOP OF STACK</rustam>")
# Out:
# 'santosh shrestha owner of 3 rolls royce and dollar 100kmb dollars and gold worth 3m why the percent dollar    at you are flabbergasted      he am not afraid top of stack'

# %%
new_df['question1'] = new_df['question1'].apply(preprocess)
new_df['question2'] = new_df['question2'].apply(preprocess)

# %%
new_df.head()
# Out:
#             id    qid1    qid2  \
# 398782  398782  496695  532029
# 115086  115086  187729  187730
# 327711  327711  454161  454162
# 367788  367788  498109  491396
# 151235  151235  237843   50930
#
#                                                 question1  \
# 398782  what is the best marketing automation tool for...
# 115086   i am poor but i want to invest  what should i do
# 327711  i am from india and live abroad  i met a guy f...
# 367788  why do so many people in the u s  hate the sou...
# 151235                 consequences of bhopal gas tragedy
#
#                                                 question2  is_duplicate
# 398782  what is the best marketing automation tool for...             1
# 115086  i am quite poor and i want to be very rich  wh...             0
# 327711  t i e t to thapar university to thapar univers...             0
# 367788  my boyfriend doesnt feel guilty when he hurts ...             0
# 151235  what was the reason behind the bhopal gas tragedy             0

# %% [markdown]
# # prepreocess based feature extraction

# %%
new_df['q1_len'] = new_df['question1'].str.len()  #length of question|
new_df['q2_len'] = new_df['question2'].str.len()

# %%
new_df['q1_num_words'] = new_df['question1'].apply(lambda row: len(row.split(" ")))
new_df['q2_num_words'] = new_df['question2'].apply(lambda row: len(row.split(" ")))
new_df.head()
# Out:
#             id    qid1    qid2  \
# 398782  398782  496695  532029
# 115086  115086  187729  187730
# 327711  327711  454161  454162
# 367788  367788  498109  491396
# 151235  151235  237843   50930
#
#                                                 question1  \
# 398782  what is the best marketing automation tool for...
# 115086   i am poor but i want to invest  what should i do
# 327711  i am from india and live abroad  i met a guy f...
# 367788  why do so many people in the u s  hate the sou...
# 151235                 consequences of bhopal gas tragedy
#
#                                                 question2  is_duplicate  \
# 398782  what is the best marketing automation tool for...             1
# 115086  i am quite poor and i want to be very rich  wh...             0
# 327711  t i e t to thapar university to thapar univers...             0
# 367788  my boyfriend doesnt feel guilty when he hurts ...             0
# 151235  what was the reason behind the bhopal gas tragedy             0
#
#         q1_len  q2_len  q1_num_words  q2_num_words
# 398782      75      76            13            13
# 115086      48      56            13            16
# 327711     104     119            28            21
# 367788      58     145            14            32
# 151235      34      49             5             9

# %%
def common_words(row):
    w1 = set(map(lambda word: word.lower().strip(), row['question1'].split(" ")))
    w2 = set(map(lambda word: word.lower().strip(), row['question2'].split(" ")))    
    return len(w1 & w2)

# %%
new_df['word_common'] = new_df.apply(common_words, axis=1)
new_df.head()
# Out:
#             id    qid1    qid2  \
# 398782  398782  496695  532029
# 115086  115086  187729  187730
# 327711  327711  454161  454162
# 367788  367788  498109  491396
# 151235  151235  237843   50930
#
#                                                 question1  \
# 398782  what is the best marketing automation tool for...
# 115086   i am poor but i want to invest  what should i do
# 327711  i am from india and live abroad  i met a guy f...
# 367788  why do so many people in the u s  hate the sou...
# 151235                 consequences of bhopal gas tragedy
#
#                                                 question2  is_duplicate  \
# 398782  what is the best marketing automation tool for...             1
# 115086  i am quite poor and i want to be very rich  wh...             0
# 327711  t i e t to thapar university to thapar univers...             0
# 367788  my boyfriend doesnt feel guilty when he hurts ...             0
# 151235  what was the reason behind the bhopal gas tragedy             0
#
#         q1_len  q2_len  q1_num_words  q2_num_words  word_common
# 398782      75      76            13            13           12
# 115086      48      56            13            16            8
# 327711     104     119            28            21            4
# 367788      58     145            14            32            1
# 151235      34      49             5             9            3

# %%
def total_words(row):
    w1 = set(map(lambda word: word.lower().strip(), row['question1'].split(" ")))
    w2 = set(map(lambda word: word.lower().strip(), row['question2'].split(" ")))    
    return (len(w1) + len(w2))

# %%
new_df['word_total'] = new_df.apply(total_words, axis=1)
new_df.head(2)
# Out:
#             id    qid1    qid2  \
# 398782  398782  496695  532029
# 115086  115086  187729  187730
#
#                                                 question1  \
# 398782  what is the best marketing automation tool for...
# 115086   i am poor but i want to invest  what should i do
#
#                                                 question2  is_duplicate  \
# 398782  what is the best marketing automation tool for...             1
# 115086  i am quite poor and i want to be very rich  wh...             0
#
#         q1_len  q2_len  q1_num_words  q2_num_words  word_common  word_total
# 398782      75      76            13            13           12          26
# 115086      48      56            13            16            8          24

# %%
new_df['word_share'] = round(new_df['word_common']/new_df['word_total'],2)
new_df.head()
# Out:
#             id    qid1    qid2  \
# 398782  398782  496695  532029
# 115086  115086  187729  187730
# 327711  327711  454161  454162
# 367788  367788  498109  491396
# 151235  151235  237843   50930
#
#                                                 question1  \
# 398782  what is the best marketing automation tool for...
# 115086   i am poor but i want to invest  what should i do
# 327711  i am from india and live abroad  i met a guy f...
# 367788  why do so many people in the u s  hate the sou...
# 151235                 consequences of bhopal gas tragedy
#
#                                                 question2  is_duplicate  \
# 398782  what is the best marketing automation tool for...             1
# 115086  i am quite poor and i want to be very rich  wh...             0
# 327711  t i e t to thapar university to thapar univers...             0
# 367788  my boyfriend doesnt feel guilty when he hurts ...             0
# 151235  what was the reason behind the bhopal gas tragedy             0
#
#         q1_len  q2_len  q1_num_words  q2_num_words  word_common  word_total  \
# 398782      75      76            13            13           12          26
# 115086      48      56            13            16            8          24
# 327711     104     119            28            21            4          38
# 367788      58     145            14            32            1          34
# 151235      34      49             5             9            3          13
#
#         word_share
# 398782        0.46
# 115086        0.33
# 327711        0.11
# 367788        0.03
# 151235        0.23

# %% [markdown]
# # Token FUzzy and Length based feature
#
# CWC min = no of common words/min of words in (q1 and q2)
# CWC max = no of common words/max of words in (q1 and q2)
# CSC min = no of common stopwords/min of stopwords in (q1 and q2)
# CSC max = no of common stopwords/max of stopwords in (q1 and q2)
# CTC min = no of common tokens/min of tokens in (q1 and q2)
# CtC max = no of common tokens/max of tokens in (q1 and q2)
#
#
# Mean Length = Tokens of q1 + token of q2 /2
# abs length   = abs(q1 tokens - q2 tokens)
# Longest substring ratio = longest substring q1 + longest substring q2 / min(token q1, token q2)
#
#
# fuzz ratio= Basic Levenshtein similarity scaled to 0–100
# When strings are similar in length and structure
#
# fuzz partial ratio= Compares the best matching substring from one string to the other
# When one string is a subset of another
#
# fuzz token sort ratio = Tokenizes, sorts, and joins strings before comparing
# When word order differs but content is similar
#
# token set ratio = Compares common and unique tokens using set logic
#  When strings share many words but differ in extras

# %%
# Advanced Features
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')


def fetch_token_features(row):
    
    q1 = row['question1']
    q2 = row['question2']
    
    SAFE_DIV = 0.0001 

    STOP_WORDS = stopwords.words("english")
    
    token_features = [0.0]*8
    
    # Converting the Sentence into Tokens: 
    q1_tokens = q1.split()
    q2_tokens = q2.split()
    
    if len(q1_tokens) == 0 or len(q2_tokens) == 0:
        return token_features

    # Get the non-stopwords in Questions
    q1_words = set([word for word in q1_tokens if word not in STOP_WORDS])
    q2_words = set([word for word in q2_tokens if word not in STOP_WORDS])
    
    #Get the stopwords in Questions
    q1_stops = set([word for word in q1_tokens if word in STOP_WORDS])
    q2_stops = set([word for word in q2_tokens if word in STOP_WORDS])
    
    # Get the common non-stopwords from Question pair
    common_word_count = len(q1_words.intersection(q2_words))
    
    # Get the common stopwords from Question pair
    common_stop_count = len(q1_stops.intersection(q2_stops))
    
    # Get the common Tokens from Question pair
    common_token_count = len(set(q1_tokens).intersection(set(q2_tokens)))
    
    
    token_features[0] = common_word_count / (min(len(q1_words), len(q2_words)) + SAFE_DIV)
    token_features[1] = common_word_count / (max(len(q1_words), len(q2_words)) + SAFE_DIV)
    token_features[2] = common_stop_count / (min(len(q1_stops), len(q2_stops)) + SAFE_DIV)
    token_features[3] = common_stop_count / (max(len(q1_stops), len(q2_stops)) + SAFE_DIV)
    token_features[4] = common_token_count / (min(len(q1_tokens), len(q2_tokens)) + SAFE_DIV)
    token_features[5] = common_token_count / (max(len(q1_tokens), len(q2_tokens)) + SAFE_DIV)
    
    # Last word of both question is same or not
    token_features[6] = int(q1_tokens[-1] == q2_tokens[-1])
    
    # First word of both question is same or not
    token_features[7] = int(q1_tokens[0] == q2_tokens[0])
    
    return token_features
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/rustamshrestha/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
token_features = new_df.apply(fetch_token_features, axis=1)

new_df["cwc_min"]       = list(map(lambda x: x[0], token_features))
new_df["cwc_max"]       = list(map(lambda x: x[1], token_features))
new_df["csc_min"]       = list(map(lambda x: x[2], token_features))
new_df["csc_max"]       = list(map(lambda x: x[3], token_features))
new_df["ctc_min"]       = list(map(lambda x: x[4], token_features))
new_df["ctc_max"]       = list(map(lambda x: x[5], token_features))
new_df["last_word_eq"]  = list(map(lambda x: x[6], token_features))
new_df["first_word_eq"] = list(map(lambda x: x[7], token_features))

# %%
new_df.head()
# Out:
#             id    qid1    qid2  \
# 398782  398782  496695  532029
# 115086  115086  187729  187730
# 327711  327711  454161  454162
# 367788  367788  498109  491396
# 151235  151235  237843   50930
#
#                                                 question1  \
# 398782  what is the best marketing automation tool for...
# 115086   i am poor but i want to invest  what should i do
# 327711  i am from india and live abroad  i met a guy f...
# 367788  why do so many people in the u s  hate the sou...
# 151235                 consequences of bhopal gas tragedy
#
#                                                 question2  is_duplicate  \
# 398782  what is the best marketing automation tool for...             1
# 115086  i am quite poor and i want to be very rich  wh...             0
# 327711  t i e t to thapar university to thapar univers...             0
# 367788  my boyfriend doesnt feel guilty when he hurts ...             0
# 151235  what was the reason behind the bhopal gas tragedy             0
#
#         q1_len  q2_len  q1_num_words  q2_num_words  ...  word_total  \
# 398782      75      76            13            13  ...          26
# 115086      48      56            13            16  ...          24
# 327711     104     119            28            21  ...          38
# 367788      58     145            14            32  ...          34
# 151235      34      49             5             9  ...          13
#
#         word_share   cwc_min   cwc_max   csc_min   csc_max   ctc_min  \
# 398782        0.46  0.874989  0.874989  0.999980  0.999980  0.923070
# 115086        0.33  0.666644  0.499988  0.714276  0.624992  0.583328
# 327711        0.11  0.000000  0.000000  0.428565  0.272725  0.149999
# 367788        0.03  0.000000  0.000000  0.000000  0.000000  0.000000
# 151235        0.23  0.749981  0.599988  0.000000  0.000000  0.599988
#
#          ctc_max  last_word_eq  first_word_eq
# 398782  0.923070           1.0            1.0
# 115086  0.466664           1.0            1.0
# 327711  0.115384           0.0            0.0
# 367788  0.000000           0.0            0.0
# 151235  0.333330           1.0            0.0
#
# [5 rows x 21 columns]

# %%
import distance

def fetch_length_features(row):
    
    q1 = row['question1']
    q2 = row['question2']
    
    length_features = [0.0]*3
    
    # Converting the Sentence into Tokens: 
    q1_tokens = q1.split()
    q2_tokens = q2.split()
    
    if len(q1_tokens) == 0 or len(q2_tokens) == 0:
        return length_features
    
    # Absolute length features
    length_features[0] = abs(len(q1_tokens) - len(q2_tokens))
    
    #Average Token Length of both Questions
    length_features[1] = (len(q1_tokens) + len(q2_tokens))/2
    
    strs = list(distance.lcsubstrings(q1, q2))
    length_features[2] = len(strs[0]) / (min(len(q1), len(q2)) + 1)
    
    return length_features

# %%
length_features = new_df.apply(fetch_length_features, axis=1)

new_df['abs_len_diff'] = list(map(lambda x: x[0], length_features))
new_df['mean_len'] = list(map(lambda x: x[1], length_features))
new_df['longest_substr_ratio'] = list(map(lambda x: x[2], length_features))

# %%
new_df.head()
# Out:
#             id    qid1    qid2  \
# 398782  398782  496695  532029
# 115086  115086  187729  187730
# 327711  327711  454161  454162
# 367788  367788  498109  491396
# 151235  151235  237843   50930
#
#                                                 question1  \
# 398782  what is the best marketing automation tool for...
# 115086   i am poor but i want to invest  what should i do
# 327711  i am from india and live abroad  i met a guy f...
# 367788  why do so many people in the u s  hate the sou...
# 151235                 consequences of bhopal gas tragedy
#
#                                                 question2  is_duplicate  \
# 398782  what is the best marketing automation tool for...             1
# 115086  i am quite poor and i want to be very rich  wh...             0
# 327711  t i e t to thapar university to thapar univers...             0
# 367788  my boyfriend doesnt feel guilty when he hurts ...             0
# 151235  what was the reason behind the bhopal gas tragedy             0
#
#         q1_len  q2_len  q1_num_words  q2_num_words  ...   cwc_max   csc_min  \
# 398782      75      76            13            13  ...  0.874989  0.999980
# 115086      48      56            13            16  ...  0.499988  0.714276
# 327711     104     119            28            21  ...  0.000000  0.428565
# 367788      58     145            14            32  ...  0.000000  0.000000
# 151235      34      49             5             9  ...  0.599988  0.000000
#
#          csc_max   ctc_min   ctc_max  last_word_eq  first_word_eq  \
# 398782  0.999980  0.923070  0.923070           1.0            1.0
# 115086  0.624992  0.583328  0.466664           1.0            1.0
# 327711  0.272725  0.149999  0.115384           0.0            0.0
# 367788  0.000000  0.000000  0.000000           0.0            0.0
# 151235  0.000000  0.599988  0.333330           1.0            0.0
#
#         abs_len_diff  mean_len  longest_substr_ratio
# 398782           0.0      13.0              0.855263
# 115086           3.0      13.5              0.224490
# 327711           6.0      23.0              0.047619
# 367788          17.0      21.5              0.050847
# 151235           4.0       7.0              0.542857
#
# [5 rows x 24 columns]

# %%
# Fuzzy Features
from fuzzywuzzy import fuzz

def fetch_fuzzy_features(row):
    
    q1 = row['question1']
    q2 = row['question2']
    
    fuzzy_features = [0.0]*4
    
    # fuzz_ratio
    fuzzy_features[0] = fuzz.QRatio(q1, q2)

    # fuzz_partial_ratio
    fuzzy_features[1] = fuzz.partial_ratio(q1, q2)

    # token_sort_ratio
    fuzzy_features[2] = fuzz.token_sort_ratio(q1, q2)

    # token_set_ratio
    fuzzy_features[3] = fuzz.token_set_ratio(q1, q2)

    return fuzzy_features

# %%
fuzzy_features = new_df.apply(fetch_fuzzy_features, axis=1)

# Creating new feature columns for fuzzy features
new_df['fuzz_ratio'] = list(map(lambda x: x[0], fuzzy_features))
new_df['fuzz_partial_ratio'] = list(map(lambda x: x[1], fuzzy_features))
new_df['token_sort_ratio'] = list(map(lambda x: x[2], fuzzy_features))
new_df['token_set_ratio'] = list(map(lambda x: x[3], fuzzy_features))

# %% [markdown]
# ##  Pairplot Analysis: Duplicate Question Detection
#
# ### Features Compared
# - **`ctc_min`**: Common token count — total shared words (includes stopwords)
# - **`cwc_min`**: Common word count — shared meaningful words (excludes stopwords)
# - **`csc_min`**: Common stopword count — shared filler words like "is", "of", "was"
#
# ###  What the Plot Shows
# Each dot is a question pair:
# - **Orange** = duplicate
# - **Blue** = non-duplicate
#
# The position of the dot shows how much overlap exists between two features. Diagonal plots show how each feature behaves on its own.
#
# ---
#
# ### Feature Comparisons
#
# ####  `ctc_min` vs `cwc_min`
# - Orange dots cluster in the **top-right** → duplicates share both total and meaningful words.
# - Blue dots are mostly **lower and scattered** → non-duplicates don’t share much.
# - Strong positive relationship → when meaningful word overlap increases, total token overlap increases too.
# - **Verdict**:  Very helpful for classification.
#
# ####  `ctc_min` vs `csc_min`
# - Orange dots are **higher**, but blue dots **mix in** → duplicates share stopwords, but so do non-duplicates.
# - Some overlap → signal exists, but not clean.
# - **Verdict**:  Moderately helpful — useful when combined with stronger features.
#
# ####  `cwc_min` vs `csc_min`
# - Orange dots show a **rising pattern** → duplicates share both meaningful and filler words.
# - Blue dots also rise slightly → not fully separable.
# - **Verdict**:  Weak alone — may help in combination.
#
# ---
#
# ### How to Judge Feature Strength (Layman Rules)
#
# | What You See | What It Means | Feature Strength |
# |--------------|----------------|------------------|
# | Orange and blue dots are clearly in different areas | Feature separates duplicates well | Strong |
# | Orange and blue dots mix together | Hard to tell duplicates apart |  Weak |
# | Orange mostly high, blue mostly low | Duplicates have more overlap |  Helpful |
# | Orange and blue both high | Some signal, but not clean |  Moderate |
# | Feature only helps when combined | Needs help from others | Not enough alone |
#
# ---
#
# ### Final Takeaways
# - **Keep `ctc_min` and `cwc_min`** — they show strong separation and are great for classification.
# - **Use `csc_min` as a supporting feature** — it adds nuance but isn’t strong alone.
# - **Combine features** — try ratios or sums like `ctc_min + cwc_min` to boost signal.
# - **Use tree-based models** — they handle feature interactions well (e.g., XGBoost, Random Forest).
# - **Visualize early** — this plot helps justify feature choices to stakeholders and teammates.

# %%
print(new_df.shape)
new_df.head()
# Out:
# (30000, 28)
#             id    qid1    qid2  \
# 398782  398782  496695  532029
# 115086  115086  187729  187730
# 327711  327711  454161  454162
# 367788  367788  498109  491396
# 151235  151235  237843   50930
#
#                                                 question1  \
# 398782  what is the best marketing automation tool for...
# 115086   i am poor but i want to invest  what should i do
# 327711  i am from india and live abroad  i met a guy f...
# 367788  why do so many people in the u s  hate the sou...
# 151235                 consequences of bhopal gas tragedy
#
#                                                 question2  is_duplicate  \
# 398782  what is the best marketing automation tool for...             1
# 115086  i am quite poor and i want to be very rich  wh...             0
# 327711  t i e t to thapar university to thapar univers...             0
# 367788  my boyfriend doesnt feel guilty when he hurts ...             0
# 151235  what was the reason behind the bhopal gas tragedy             0
#
#         q1_len  q2_len  q1_num_words  q2_num_words  ...   ctc_max  \
# 398782      75      76            13            13  ...  0.923070
# 115086      48      56            13            16  ...  0.466664
# 327711     104     119            28            21  ...  0.115384
# 367788      58     145            14            32  ...  0.000000
# 151235      34      49             5             9  ...  0.333330
#
#         last_word_eq  first_word_eq  abs_len_diff  mean_len  \
# 398782           1.0            1.0           0.0      13.0
# 115086           1.0            1.0           3.0      13.5
# 327711           0.0            0.0           6.0      23.0
# 367788           0.0            0.0          17.0      21.5
# 151235           1.0            0.0           4.0       7.0
#
#         longest_substr_ratio  fuzz_ratio  fuzz_partial_ratio  \
# 398782              0.855263          99                  99
# 115086              0.224490          69                  67
# 327711              0.047619          42                  42
# 367788              0.050847          37                  50
# 151235              0.542857          60                  71
#
#         token_sort_ratio  token_set_ratio
# 398782                99               99
# 115086                67               74
# 327711                39               46
# 367788                38               40
# 151235                48               69
#
# [5 rows x 28 columns]

# %%
sns.pairplot(
    new_df[['ctc_min', 'cwc_min', 'csc_min', 'is_duplicate']],
    hue='is_duplicate',
    plot_kws={'alpha': 0.5}  # transparency 
)

# %% [markdown]
# Color Legend:
#
#    ##Orange dots represent question pairs that are duplicates (they ask the same thing).
#
#     #Blue dots represent question pairs that are not duplicates (they ask different things).
#
# Diagonal Curves (Distributions):
#
#     #Duplicate questions tend to have higher values across all three features.
#
#     #This means they share more words, stopwords, and tokens, which makes sense—similar questions use similar language.
#
# Scatterplots (Feature Relationships):
#
#     #Theres a strong positive relationship between shared meaningful words (cwc_min) and total shared tokens (ctc_min).
#
#     #Duplicate questions cluster in the upper-right corner, showing high overlap. made transparent plot so to see overlap
#     # Even shared stopwords (csc_min) contribute to identifying duplicates, though with a bit more overlap between the two classes.
#
# Feature Discriminativeness:
#
#     #These features clearly help separate duplicate questions from non-duplicates.
#
#     #They are easy to understand and effective for building models that detect when two questions mean the same thing.
#
#
#
# This visualization shows that when two questions share a lot of words especially meaningful onesheyre very likely to be duplicates. The patterns are clear and consistent: duplicates cluster together and show higher overlap across all metrics. These features are not just technicaltheyre intuitive, reliable, and valuable for any system that needs to automatically detect similar or repeated questions. Whether you're building a helpdesk, a chatbot, or a search engine, these insights help ensure users get accurate, consolidated answers without redundancy.

# %%
sns.pairplot(new_df[['ctc_max', 'cwc_max', 'csc_max', 'is_duplicate']],hue='is_duplicate', kind = 'reg',plot_kws={'line_kws':{'color':'green'}})

# %% [markdown]
# Diagonal Curves (Distributions):
#
#     @ Duplicate questions tend to have higher values across all three features.
#
#     @ This means they share more words, including both meaningful terms and common filler words like “the” or “is” which makes sense, because similar questions often use similar language.
#
# catterplots (Feature Relationships):
#
#     @ Theres a strong positive relationship between shared meaningful words (cwc_max) and total shared tokens (ctc_max).
#
#     @ Duplicate questions cluster in the upper-right corner, showing high overlap. The plot was made slightly transparent to help visualize where duplicates and non-duplicates overlap.
#
#     @ Even shared filler words (csc_max) contribute to identifying duplicates, though theres a bit more mixing between the two groups.
#
# Feature Discriminativeness:
#
#     @ These features clearly help separate duplicate questions from non-duplicates.
#
#     @ Theyre easy to interpret and effective for building systems that understand when two questions are asking the same thing.
#
#
#
# This visualization confirms a simple but powerful insight: when two questions share a lot of words especially meaningful ones theyre very likely to be duplicates. The patterns are clear and consistent duplicates group together and show higher overlap across all three metrics. These features arent just technical theyre intuitive and reliable. Whether youre building a helpdesk, a chatbot, or a search engine, this kind of analysis helps ensure users get accurate, consolidated answers without repetition or confusion. Its a smart way to improve user experience and reduce redundancy.

# %%
sns.pairplot(new_df[['last_word_eq', 'first_word_eq', 'is_duplicate']],hue='is_duplicate', kind='reg')

# %% [markdown]
# # we find that  if last word and or first word is not equal there is higher probability we can get non duplicate question classified
# # when matches last word equal when first word match slight highter probability of not duplicate quesiton

# %%
sns.pairplot(new_df[['mean_len', 'abs_len_diff','longest_substr_ratio', 'is_duplicate']],hue='is_duplicate')

# %% [markdown]
# ** the feature for  mean and absollength   doesnot actually give significant insight as the both overlap
# but longest substr could be more helpful and strong feature to classify duplicaes **

# %% [markdown]
# # fuzzy features viz

# %%
sns.pairplot(new_df[['fuzz_ratio', 'fuzz_partial_ratio','token_sort_ratio','token_set_ratio', 'is_duplicate']],hue='is_duplicate')

# %% [markdown]
# ---all of feature provide good insights and they are strong enough to classify duplicates as there is not high overlaps like we saw in above diagram of absol length diff and ean length diff---

# %%
# Using TSNE for Dimentionality reduction for 15 Features(Generated after cleaning the data) to 3 dimention

from sklearn.preprocessing import MinMaxScaler

X = MinMaxScaler().fit_transform(new_df[['cwc_min', 'cwc_max', 'csc_min', 'csc_max' , 'ctc_min' , 'ctc_max' , 'last_word_eq', 'first_word_eq' , 'abs_len_diff' , 'mean_len' , 'token_set_ratio' , 'token_sort_ratio' ,  'fuzz_ratio' , 'fuzz_partial_ratio' , 'longest_substr_ratio']])
y = new_df['is_duplicate'].values

# %%
from sklearn.manifold import TSNE

tsne2d = TSNE(
    n_components=2,
    init='random', # pca
    random_state=101,
    method='barnes_hut',
    max_iter=1000,
    verbose=2,
    angle=0.5
).fit_transform(X)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 30000 samples in 0.164s...
# [t-SNE] Computed neighbors for 30000 samples in 14.762s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 30000
# [t-SNE] Computed conditional probabilities for sample 2000 / 30000
# [t-SNE] Computed conditional probabilities for sample 3000 / 30000
# [t-SNE] Computed conditional probabilities for sample 4000 / 30000
# [t-SNE] Computed conditional probabilities for sample 5000 / 30000
# [t-SNE] Computed conditional probabilities for sample 6000 / 30000
# [t-SNE] Computed conditional probabilities for sample 7000 / 30000
# [t-SNE] Computed conditional probabilities for sample 8000 / 30000
# [t-SNE] Computed conditional probabilities for sample 9000 / 30000
# [t-SNE] Computed conditional probabilities for sample 10000 / 30000
# [t-SNE] Computed conditional probabilities for sample 11000 / 30000
# [t-SNE] Computed conditional probabilities for sample 12000 / 30000
# [t-SNE] Computed conditional probabilities for sample 13000 / 30000
# [t-SNE] Computed conditional probabilities for sample 14000 / 30000
# [t-SNE] Computed conditional probabilities for sample 15000 / 30000
# [t-SNE] Computed conditional probabilities for sample 16000 / 30000
# [t-SNE] Computed conditional probabilities for sample 17000 / 30000
# [t-SNE] Computed conditional probabilities for sample 18000 / 30000
# [t-SNE] Computed conditional probabilities for sample 19000 / 30000
# [t-SNE] Computed conditional probabilities for sample 20000 / 30000
# [t-SNE] Computed conditional probabilities for sample 21000 / 30000
# [t-SNE] Computed conditional probabilities for sample 22000 / 30000
# [t-SNE] Computed conditional probabilities for sample 23000 / 30000
# [t-SNE] Computed conditional probabilities for sample 24000 / 30000
# [t-SNE] Computed conditional probabilities for sample 25000 / 30000
# [t-SNE] Computed conditional probabilities for sample 26000 / 30000
# [t-SNE] Computed conditional probabilities for sample 27000 / 30000
# [t-SNE] Computed conditional probabilities for sample 28000 / 30000
# [t-SNE] Computed conditional probabilities for sample 29000 / 30000
# [t-SNE] Computed conditional probabilities for sample 30000 / 30000
# [t-SNE] Mean sigma: 0.070298
# [t-SNE] Computed conditional probabilities in 2.063s
# [t-SNE] Iteration 50: error = 109.7970428, gradient norm = 0.0224615 (50 iterations in 49.127s)
# [t-SNE] Iteration 100: error = 89.5017853, gradient norm = 0.0079523 (50 iterations in 34.865s)
# [t-SNE] Iteration 150: error = 85.3385925, gradient norm = 0.0047529 (50 iterations in 27.828s)
# [t-SNE] Iteration 200: error = 83.3667145, gradient norm = 0.0033248 (50 iterations in 29.104s)
# [t-SNE] Iteration 250: error = 82.2169571, gradient norm = 0.0026644 (50 iterations in 30.173s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 82.216957
# [t-SNE] Iteration 300: error = 3.3749783, gradient norm = 0.0074568 (50 iterations in 27.052s)
# [t-SNE] Iteration 350: error = 2.7565968, gradient norm = 0.0073797 (50 iterations in 25.959s)
# [t-SNE] Iteration 400: error = 2.4220853, gradient norm = 0.0069200 (50 iterations in 24.173s)
# [t-SNE] Iteration 450: error = 2.2115965, gradient norm = 0.0064963 (50 iterations in 24.496s)
# [t-SNE] Iteration 500: error = 2.0660412, gradient norm = 0.0061687 (50 iterations in 23.612s)
# [t-SNE] Iteration 550: error = 1.9599497, gradient norm = 0.0058301 (50 iterations in 26.733s)
# [t-SNE] Iteration 600: error = 1.8802619, gradient norm = 0.0054116 (50 iterations in 24.801s)
# [t-SNE] Iteration 650: error = 1.8187301, gradient norm = 0.0050482 (50 iterations in 23.664s)
# [t-SNE] Iteration 700: error = 1.7699258, gradient norm = 0.0046658 (50 iterations in 25.315s)
# [t-SNE] Iteration 750: error = 1.7304654, gradient norm = 0.0043538 (50 iterations in 23.383s)
# [t-SNE] Iteration 800: error = 1.6979563, gradient norm = 0.0040638 (50 iterations in 24.605s)
# [t-SNE] Iteration 850: error = 1.6706986, gradient norm = 0.0037963 (50 iterations in 22.638s)
# [t-SNE] Iteration 900: error = 1.6473842, gradient norm = 0.0035790 (50 iterations in 24.072s)
# [t-SNE] Iteration 950: error = 1.6275277, gradient norm = 0.0033267 (50 iterations in 24.598s)
# [t-SNE] Iteration 1000: error = 1.6104279, gradient norm = 0.0031122 (50 iterations in 26.914s)
# [t-SNE] KL divergence after 1000 iterations: 1.610428

# %%
# To view the first 5 rows of the scaled NumPy array X
print(X[:5])
# Out:
# [[0.87499271 0.87499271 0.99998625 0.99998625 0.92307351 0.92307351
#   1.         1.         0.         0.09885932 0.99       0.99
#   0.99       0.99       0.86060855]
#  [0.66664722 0.49998958 0.71427997 0.62499609 0.58333081 0.46666542
#   1.         1.         0.01287554 0.1026616  0.74       0.67
#   0.69       0.67       0.22589286]
#  [0.         0.         0.42856798 0.2727265  0.14999985 0.11538463
#   0.         0.         0.02575107 0.17490494 0.46       0.39
#   0.42       0.42       0.04791667]
#  [0.         0.         0.         0.         0.         0.
#   0.         0.         0.07296137 0.1634981  0.4        0.38
#   0.37       0.5        0.05116525]
#  [0.74998438 0.5999905  0.         0.         0.5999904  0.33333096
#   1.         0.         0.01716738 0.05323194 0.69       0.48
#   0.6        0.71       0.54625   ]]

# %%
x_df = pd.DataFrame({'x':tsne2d[:,0], 'y':tsne2d[:,1] ,'label':y})

# draw the plot in appropriate place in the grid
sns.lmplot(data=x_df, x='x', y='y', hue='label', fit_reg=False, height=8,palette="Set1",markers=['s','o'])

# %%
tsne3d = TSNE(
    n_components=3,
    init='random', # pca
    random_state=101,
    method='barnes_hut',
    max_iter=1000,
    verbose=2,
    angle=0.5
).fit_transform(X)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 30000 samples in 0.282s...
# [t-SNE] Computed neighbors for 30000 samples in 19.072s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 30000
# [t-SNE] Computed conditional probabilities for sample 2000 / 30000
# [t-SNE] Computed conditional probabilities for sample 3000 / 30000
# [t-SNE] Computed conditional probabilities for sample 4000 / 30000
# [t-SNE] Computed conditional probabilities for sample 5000 / 30000
# [t-SNE] Computed conditional probabilities for sample 6000 / 30000
# [t-SNE] Computed conditional probabilities for sample 7000 / 30000
# [t-SNE] Computed conditional probabilities for sample 8000 / 30000
# [t-SNE] Computed conditional probabilities for sample 9000 / 30000
# [t-SNE] Computed conditional probabilities for sample 10000 / 30000
# [t-SNE] Computed conditional probabilities for sample 11000 / 30000
# [t-SNE] Computed conditional probabilities for sample 12000 / 30000
# [t-SNE] Computed conditional probabilities for sample 13000 / 30000
# [t-SNE] Computed conditional probabilities for sample 14000 / 30000
# [t-SNE] Computed conditional probabilities for sample 15000 / 30000
# [t-SNE] Computed conditional probabilities for sample 16000 / 30000
# [t-SNE] Computed conditional probabilities for sample 17000 / 30000
# [t-SNE] Computed conditional probabilities for sample 18000 / 30000
# [t-SNE] Computed conditional probabilities for sample 19000 / 30000
# [t-SNE] Computed conditional probabilities for sample 20000 / 30000
# [t-SNE] Computed conditional probabilities for sample 21000 / 30000
# [t-SNE] Computed conditional probabilities for sample 22000 / 30000
# [t-SNE] Computed conditional probabilities for sample 23000 / 30000
# [t-SNE] Computed conditional probabilities for sample 24000 / 30000
# [t-SNE] Computed conditional probabilities for sample 25000 / 30000
# [t-SNE] Computed conditional probabilities for sample 26000 / 30000
# [t-SNE] Computed conditional probabilities for sample 27000 / 30000
# [t-SNE] Computed conditional probabilities for sample 28000 / 30000
# [t-SNE] Computed conditional probabilities for sample 29000 / 30000
# [t-SNE] Computed conditional probabilities for sample 30000 / 30000
# [t-SNE] Mean sigma: 0.070298
# [t-SNE] Computed conditional probabilities in 3.596s
# [t-SNE] Iteration 50: error = 110.3122711, gradient norm = 0.0153051 (50 iterations in 148.564s)
# [t-SNE] Iteration 100: error = 86.1325760, gradient norm = 0.0045362 (50 iterations in 67.374s)
# [t-SNE] Iteration 150: error = 82.9011688, gradient norm = 0.0022974 (50 iterations in 55.479s)
# [t-SNE] Iteration 200: error = 81.6175079, gradient norm = 0.0015302 (50 iterations in 58.160s)
# [t-SNE] Iteration 250: error = 80.8940277, gradient norm = 0.0011333 (50 iterations in 61.123s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.894028
# [t-SNE] Iteration 300: error = 2.9520676, gradient norm = 0.0038420 (50 iterations in 85.126s)
# [t-SNE] Iteration 350: error = 2.3400798, gradient norm = 0.0030945 (50 iterations in 81.812s)
# [t-SNE] Iteration 400: error = 2.0259089, gradient norm = 0.0024711 (50 iterations in 71.571s)
# [t-SNE] Iteration 450: error = 1.8406055, gradient norm = 0.0020625 (50 iterations in 89.402s)
# [t-SNE] Iteration 500: error = 1.7187834, gradient norm = 0.0017577 (50 iterations in 90.407s)
# [t-SNE] Iteration 550: error = 1.6328369, gradient norm = 0.0015297 (50 iterations in 71.845s)
# [t-SNE] Iteration 600: error = 1.5709167, gradient norm = 0.0013124 (50 iterations in 71.428s)
# [t-SNE] Iteration 650: error = 1.5255346, gradient norm = 0.0011269 (50 iterations in 72.046s)
# [t-SNE] Iteration 700: error = 1.4928739, gradient norm = 0.0008961 (50 iterations in 71.173s)
# [t-SNE] Iteration 750: error = 1.4696410, gradient norm = 0.0007174 (50 iterations in 71.122s)
# [t-SNE] Iteration 800: error = 1.4549228, gradient norm = 0.0004947 (50 iterations in 76.472s)
# [t-SNE] Iteration 850: error = 1.4447012, gradient norm = 0.0004168 (50 iterations in 120.456s)
# [t-SNE] Iteration 900: error = 1.4357339, gradient norm = 0.0003896 (50 iterations in 114.096s)
# [t-SNE] Iteration 950: error = 1.4277465, gradient norm = 0.0003474 (50 iterations in 103.309s)
# [t-SNE] Iteration 1000: error = 1.4212811, gradient norm = 0.0002867 (50 iterations in 83.948s)
# [t-SNE] KL divergence after 1000 iterations: 1.421281

# %%
import plotly.graph_objs as go
import plotly.tools as tls
import plotly.offline as py
py.init_notebook_mode(connected=True)

trace1 = go.Scatter3d(
    x=tsne3d[:,0],
    y=tsne3d[:,1],
    z=tsne3d[:,2],
    mode='markers',
    marker=dict(
        sizemode='diameter',
        color = y,
        colorscale = 'Portland',
        colorbar = dict(title = 'duplicate'),
        line=dict(color='rgb(255, 255, 255)'),
        opacity=0.75
    )
)

data=[trace1]
layout=dict(height=800, width=800, title='3d embedding with engineered features')
fig=dict(data=data, layout=layout)
py.iplot(fig, filename='3DBubble')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="8c0669aa-07bd-4604-9445-2c88d3a0b210" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("8c0669aa-07bd-4604-9445-2c88d3a0b210")) {                    Plotly.newPlot(                        "8c0669aa-07bd-4604-9445-2c88d3a0b210",                        [{"marker":{"color":{"dtype":"i1","bdata":"..."},"colorbar":{"title":{"text":"duplicate"}},"colorscale":[[0.0,"rgb(12,51,131)"],[0.25,"rgb(10,136,186)"],[0.5,"rgb(242,211,56)"],[0.75,"rgb(242,143,56)"],[1.0,"rgb(217,30,30)"]],"line":{"color":"rgb(255, 255, 255)"},"opacity":0.75,"sizemode":"diameter"},"mode":"markers","x":{"dtype":"f4","bdata":"N9dbwdWcO8GwJtVBkruDQHVVj8GVZoJBBK17QT5HRUGdQGBB8nM9wQehm0DCjTZBrwGEwZpOlcGiH+pAh9e1Qce4YMHLcJ1BeiOUwagG+UAy4yzB2RorQWquPsFBncLAm9q7QWXkkUGEm11BTjlQQBoY4b+BBOlA6L04wSChM0F6xmDBTZpUQUyUMEHwXMC\u002fObYWwUY5KkFmiRNBa6RCwdw4ksEmJZvA57SYwCywkMBVzZBB7FoMQYoSm8G4BJJAbMMIQR\u002frzsBuqxm+6oTVQaI2iMFJewnBzLZtwZdH2kEraSBAvOqdwWSiv0FK25JAWlNfQdCan0FQZSrBTr\u002fgwN4Sx0F9JNI\u002f0VhGwbMdGEFPL91A9mj+Pjuz0EAKLS9AJpmiweW3iUEHe1fBX6SMQVK4I8G65lPBSFrfwY1G577nslNBsgwhQGLqtsBSJ0lBG+DVQIRbPj8QfY\u002fAsFp4QBoXwsD45\u002fdBPjrtQDRg5kFC6+pA\u002fIjNwehoxkHR13PBY73zwMmGJ8H+nJNB3uOAQUaNjECBm8rAdF3yP\u002fQwhr6vJHDARwYIv2bgkEFTEBnBWvjpwEaTJEDJGxzB0ITjwXnkL8G\u002fq8dAn4vOwBCCisHH\u002fnDBOit1QYA2ZUBkfxi\u002fQfKewOF2m0A\u002fjN1B39KnwZ6HCUHXlYPAn8HdQIDrJ0F+2bHAgoudwUAXmb0wuT5B5803QYrpWcC\u002fBbY9YN\\u002fccENYSdBZ3p5wGepIEFoFZbAXVExQc6lg0FVYdFAtPmEwej5BEEm2p5B1iAmwHvHpcH9MkXB6MY+weETtED4O15B7AIuQb8gicCTY5G\u002f6iINwcR140DuCp2\u002fkVwIP0MyxkD8l4XBI84XQZ\u002fJp8E5dEC\u002fqHcKwKPZysEbbUdBrIbZv\u002fijCD\u002fMtqpAQo64P9h2BUETrAfA\u002ff37wLsrLEAadh1B4hY7QAXCBsD8GP2\u002fERmSwOvL9sCsSyfBF3h4wc0RjkDlF0tBmgmiQfeuTj8\u002fzMFB+vidv1wuusFC7AXBeNaTQWB2ZcAdUFrBPqybQW2uTD1zBHjAMx\u002fCwL77SkE9u\u002fe\u002fa4JswUmtVEEAfCZBG7dXwbpQYsEdO6nBI0buQH9TxEHBYpdA5Bv+wNUoCUCj6k\u002fBbqSmQSLG0kAMou1ATiCxQBX0JUGsd\u002fXAJdVwwekKlD\u002fJ2CrBsJ9UwWewA8HU0Nk\u002fRafrQEvfpj\u002fe\u002fcHAj2KHwfSXG8ED9JK\u002fxvMiwQb\u002fvUAV\u002fExBlVHZwLqG9cBlOoDBWVqGQEcRjz9wkZRBv\u002fSAwDRYPMG+o5LBU7aQQQQd48AqjGTBYSySwYuUHUFBS7dBJcl5wSEvB0HtHgNB7JJdQRBHDMHul6BBbLz5QDeYTcBmK1NBgB1fwS+QccHLQ9nAr0MpQFD6iT79QrPAwduRwYMpiMCafRnBwZnlwDAYFUHJ02TBthWCwTucdME7uNNA48uLP79h6UC1NY5BgoNvwY\\u002fcDuf5g\u002f\u002fX+eQU7\u002f58BL0\u002fVB38KNQfTVxUFQaKNApQI+QVmAm0Ht+j\u002fB\u002fOogwQe1McFNKsjB1HkHQWabPkFj+njAIAV2QJDDKECMRuXAIbMOwUj2vEF4cBbApDT\u002fv4bLF0HDB0BAciMfQL+5kcABtTTBK+7BwCpcgUEu9Z\u002fBreERQZNbdMFPWC\u002fBpz+8vka2SsH8sprBN\u002f4DQHRryMAPDc9AakANQeC0lUGdKSPA7GCtPoI9o8FSR5jAYTVVP2oygcEEW65Af0lxwU+I1ED5XNm\u002fNnEhv57FD0AmIKk\u002fU0H6P+pMgsEqGNfABgyzv15K00C4emrBaKaUQQqBYcBsvmM\u002fXNF3wbj5kb93dRnBW9TPwLt14EG6MKK\u002fa7ZfQcI5e0C6LSrB5H3xwAaivsFVmx5A6CTKwWXxvkElroK+7feUQFxQYkEUYaU+PAm1wQbcREHrn9nAsdQKwcT1oD\u002fAb7dBGdsgwfSLwsCD2o9B2m1uwe3vx8AQIlLBGdiRQREAwMH3bGTBxhmhwZpZCcE3YIZBrXqQPpyWh7+yQcJAFw6cQdXMo0FaOwDArX4GQchG2MAJxI3B4\u002fwlQSmylcBFQKHAaDZyvhn\u002frT92VSfBIhfKQCy7okGxFFHBleqmwX5y4kBT4rpARaq9wFhcvcGZvkJBTepbwTCYxsHfI+FBn9nDPwYdeUEO0rbB3LyMwVcvcEBN4VHBpOl1QS3jEcGsHYhBQO2vQfLCZMH ...

# %%
ques_df = new_df[['question1','question2']]
ques_df.head()
# Out:
#                                                 question1  \
# 398782  what is the best marketing automation tool for...
# 115086   i am poor but i want to invest  what should i do
# 327711  i am from india and live abroad  i met a guy f...
# 367788  why do so many people in the u s  hate the sou...
# 151235                 consequences of bhopal gas tragedy
#
#                                                 question2
# 398782  what is the best marketing automation tool for...
# 115086  i am quite poor and i want to be very rich  wh...
# 327711  t i e t to thapar university to thapar univers...
# 367788  my boyfriend doesnt feel guilty when he hurts ...
# 151235  what was the reason behind the bhopal gas tragedy

# %%
final_df = new_df.drop(columns=['id','qid1','qid2','question1','question2'])
print(final_df.shape)
final_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 final_df = new_df.drop(columns=['id','qid1','qid2','question1','question2'])
#       2 print(final_df.shape)
#       3 final_df.head()
#
# NameError: name 'new_df' is not defined

# %%
from sklearn.feature_extraction.text import CountVectorizer
# merge texts
questions = list(ques_df['question1']) + list(ques_df['question2'])

cv = CountVectorizer(max_features=3000)
q1_arr, q2_arr = np.vsplit(cv.fit_transform(questions).toarray(),2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from sklearn.feature_extraction.text import CountVectorizer
#       2 # merge texts
# ----> 3 questions = list(ques_df['question1']) + list(ques_df['question2'])
#       5 cv = CountVectorizer(max_features=3000)
#       6 q1_arr, q2_arr = np.vsplit(cv.fit_transform(questions).toarray(),2)
#
# NameError: name 'ques_df' is not defined
